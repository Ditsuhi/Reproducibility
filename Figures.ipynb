# %% [markdown]
# <a href="https://colab.research.google.com/github/Ditsuhi/Reproducibility/blob/master/Figures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here are listed the figures that were used in the following paper: "Air Quality Prediction in Smart Cities Using Machine Learning Technologies Based on Sensor Data: A Review".
#
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig1/AS:875696410882048@1585793702982/Review-workflow.ppm)
#
# <p align="center">Figure 1. Review workflow.</p>
#
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig2/AS:875696415051776@1585793703039/The-evolution-of-the-publications.ppm)
#
# <p align="center">Figure 2. The evolution of the publications.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig3/AS:875696415068160@1585793703089/Case-study-of-the-publications.ppm)
#
# <p align="center">Figure 3. Case study of the publications.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig4/AS:875696415055882@1585793703157/Used-machine-learning-algorithms.ppm)
#
# <p align="center">Figure 4. Used machine learning algorithms.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig5/AS:875696415055883@1585793703229/Number-of-publications-per-machine-learning-algorithms-throughout-the-years.ppm)
#
# <p align="center">Figure 5. Number of publications per machine learning algorithms throughout the years.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig6/AS:875696415076372@1585793703286/Used-evaluation-metrics.ppm)
#
# <p align="center">Figure 6. Used evaluation metrics.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig7/AS:875696415076373@1585793703331/Pollutants-as-a-prediction-target.ppm)
#
# <p align="center">Figure 7. Pollutants as a prediction target.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig8/AS:875696415051777@1585793703376/Number-of-the-publications-focused-on-the-prediction-of-PM-25-and-PM-10-over-the-years.ppm)
#
# <p align="center">Figure 8. Number of the publications focused on the prediction of PM2.5 and PM10 over the years.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig9/AS:875696415076375@1585793703427/Countries-distribution-per-pollutant.ppm)#
#
# <p align="center">Figure 9. Countries distribution per pollutant.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig10/AS:875696415076376@1585793703531/Time-granularity.ppm)
#
# <p align="center">Figure 10. Time granularity.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig11/AS:875696415051788@1585793703579/Data-rates.ppm)
#
# <p align="center">Figure 11. Data rates.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig12/AS:875696415076378@1585793703626/Dataset-types-used-in-the-selected-publications.ppm)
#
# <p align="center">Figure 12. Dataset types used in the selected publications.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig13/AS:875696415051806@1585793703672/Data-accessibility-in-the-selected-publications.ppm)
#
# <p align="center">Figure 13. Data accessibility in the selected publications.</p>
# <p>&nbsp;</p>
# <p>&nbsp;</p>
#
# ![alt text](https://www.researchgate.net/publication/340371839/figure/fig14/AS:875696415059980@1585793703724/The-evolution-of-data-accessibility.ppm)
#
# <p align="center"> Figure 14. The evolution of data accessibility. </p>
